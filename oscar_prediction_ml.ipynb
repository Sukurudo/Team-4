# %%
#Add Dependencies
import pandas as pd
import psycopg2 as pg

# %%
#Read Data from the PostgressSql
conn = pg.connect(user = "postgres",
                                  password = "akshaj10",
                                  host = "127.0.0.1",
                                  port = "5432",
                                  database = "movie_data")
sql = "Select * From movies;"
dat = pd.read_sql_query(sql, conn)
conn = None

# %%
#Load Data into Pandas Data frame and Display the dataframe.
dat.head(10)
# Out:
#    index                                      wikipedia_url  year  \
# 0      0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1      1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3      3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# 5      5        https://en.wikipedia.org/wiki/The_Ambulance  1990
# 6   1435  https://en.wikipedia.org/wiki/Pie_in_the_Sky_(...  1996
# 7      6  https://en.wikipedia.org/wiki/American_Dream_(...  1990
# 8      7  https://en.wikipedia.org/wiki/American_Ninja_4...  1990
# 9      8      https://en.wikipedia.org/wiki/Another_48_Hrs.  1990
#
#                                imdb_link  \
# 0  https://www.imdb.com/title/tt0098987/
# 1  https://www.imdb.com/title/tt0098994/
# 2  https://www.imdb.com/title/tt0099005/
# 3  https://www.imdb.com/title/tt0099012/
# 4  https://www.imdb.com/title/tt0099018/
# 5  https://www.imdb.com/title/tt0099026/
# 6  https://www.imdb.com/title/tt0114131/
# 7  https://www.imdb.com/title/tt0099028/
# 8  https://www.imdb.com/title/tt0101326/
# 9  https://www.imdb.com/title/tt0099044/
#
#                                             based_on  \
# 0                       {Characters,"by Rex Weiner"}
# 1  {"the novel","After Dark, My Sweet",by,"Jim Th...
# 2           {"Air America",by,"Christopher Robbins"}
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
# 9  {"Characters by","Roger Spottiswoode","Walter ...
#
#                                             starring  \
# 0  {"Andrew Dice Clay","Wayne Newton","Priscilla ...
# 1  {"Jason Patric","Rachel Ward","Bruce Dern","Ge...
# 2  {"Mel Gibson","Robert Downey Jr.","Nancy Travi...
# 3  {"Alec Baldwin","Blythe Danner","Judy Davis","...
# 4    {"Paul Hogan","Elias Koteas","Linda Kozlowski"}
# 5  {"Eric Roberts","James Earl Jones","Red Button...
# 6  {"Josh Charles","Anne Heche","John Goodman","C...
# 7                                               None
# 8  {"Michael Dudikoff","David Bradley","James Boo...
# 9  {"Eddie Murphy","Nick Nolte","Brion James","Ed...
#
#                                       cinematography  \
# 0                                        Oliver Wood
# 1                                       Mark Plummer
# 2                                      Roger Deakins
# 3                                     Carlo Di Palma
# 4                                       Russell Boyd
# 5                                    Jacques Haitkin
# 6                                        Bernd Heinl
# 7  {"Tom Hurwitz","Mathieu Roberts","Nesya Shapiro"}
# 8                                               None
# 9                                Matthew F. Leonetti
#
#                               country  \
# 0                       United States
# 1                       United States
# 2                       United States
# 3                       United States
# 4                                  US
# 5                       United States
# 6                       United States
# 7  {"United States","United Kingdom"}
# 8           {"United States",Lesotho}
# 9                       United States
#
#                                             director  \
# 0                                       Renny Harlin
# 1                                        James Foley
# 2                                 Roger Spottiswoode
# 3                                        Woody Allen
# 4                                       John Cornell
# 5                                        Larry Cohen
# 6                                       Bryan Gordon
# 7  {"Barbara Kopple",Co-directors:,"Cathy Caplan"...
# 8                                   Cedric Sundstrom
# 9                                        Walter Hill
#
#                      distributor  ... release_date      revenue runtime  \
# 0               20th Century Fox  ...   1990-07-11   20423389.0   104.0
# 1                Avenue Pictures  ...   1990-08-24    2700000.0   114.0
# 2               TriStar Pictures  ...   1990-08-10   33461269.0   112.0
# 3                 Orion Pictures  ...   1990-12-25    7331647.0   102.0
# 4             Paramount Pictures  ...   1990-12-21    6939946.0    95.0
# 5  Triumph Releasing Corporation  ...   1989-11-23          NaN    91.0
# 6             Fine Line Features  ...   1996-02-09          NaN    95.0
# 7                 Prestige Films  ...   1990-09-28     269823.0    98.0
# 8                   Cannon Group  ...   1990-10-30          NaN    99.0
# 9             Paramount Pictures  ...   1990-06-08  153518974.0    95.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 7           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 8           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 9  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...  Released
#
#                                              tagline  \
# 0                Kojak. Columbo. Dirty Harry. Wimps.
# 1                    All they risked was everything.
# 2            The few. The proud. The totally insane.
# 3                                               None
# 4                           Who does he think he is?
# 5        You'll be in perfect health before you die.
# 6  The only thing that stands in the way of fate ...
# 7  The award-winning film of American lives, Amer...
# 8                                               None
# 9                         The boys are back in town.
#
#                                 title  video vote_average  vote_count
# 0     The Adventures of Ford Fairlane  False          6.2        72.0
# 1                After Dark, My Sweet  False          6.5        17.0
# 2                         Air America  False          5.3       146.0
# 3                               Alice  False          6.3        57.0
# 4                     Almost an Angel  False          5.6        23.0
# 5                       The Ambulance  False          6.0        21.0
# 6                      Pie in the Sky  False          7.0         2.0
# 7                      American Dream  False          6.0         2.0
# 8  American Ninja 4: The Annihilation  False          4.8        31.0
# 9                     Another 48 Hrs.  False          5.8       205.0
#
# [10 rows x 37 columns]

# %%
#Data Clean Up ,Preprocessing and Filtering

# %%
#Classification (RandomForestClassification)

# %%
# Naive Bayes Classifier Model for Movie Review Sentiment Analysis
