# %%
#Add Dependencies
import pandas as pd
import numpy as np
# import psycopg2 as pg
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
read_file = "../Working/movies_metadata.csv"
write_file = "../Resources/movies_clean.csv"

#read_file = "/Users/archieanand/Desktop/Analysis/Working/movies_metadata.csv"
#write_file = "/Users/archieanand/Desktop/Analysis/Working/movies_clean.csv"

# %%
# Import our input dataset
movies_df = pd.read_csv(read_file , low_memory=False, index_col="imdb_id")

# %%
#Check imported Dataset
movies_df.head()
# Out:
#            adult                              belongs_to_collection    budget  \
# imdb_id
# tt0114709  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# tt0113497  False                                                NaN  65000000
# tt0113228  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# tt0114885  False                                                NaN  16000000
# tt0113041  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                                       genres  \
# imdb_id
# tt0114709  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# tt0113497  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# tt0113228  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# tt0114885  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt0113041                     [{'id': 35, 'name': 'Comedy'}]
#
#                                        homepage     id original_language  \
# imdb_id
# tt0114709  http://toystory.disney.com/toy-story    862                en
# tt0113497                                   NaN   8844                en
# tt0113228                                   NaN  15602                en
# tt0114885                                   NaN  31357                en
# tt0113041                                   NaN  11862                en
#
#                         original_title  \
# imdb_id
# tt0114709                    Toy Story
# tt0113497                      Jumanji
# tt0113228             Grumpier Old Men
# tt0114885            Waiting to Exhale
# tt0113041  Father of the Bride Part II
#
#                                                     overview popularity  ...  \
# imdb_id                                                                  ...
# tt0114709  Led by Woody, Andy's toys live happily in his ...  21.946943  ...
# tt0113497  When siblings Judy and Peter discover an encha...  17.015539  ...
# tt0113228  A family wedding reignites the ancient feud be...    11.7129  ...
# tt0114885  Cheated on, mistreated and stepped on, the wom...   3.859495  ...
# tt0113041  Just when George Banks has recovered from his ...   8.387519  ...
#
#           release_date      revenue runtime  \
# imdb_id
# tt0114709   1995-10-30  373554033.0    81.0
# tt0113497   1995-12-15  262797249.0   104.0
# tt0113228   1995-12-22          0.0   101.0
# tt0114885   1995-12-22   81452156.0   127.0
# tt0113041   1995-02-10   76578911.0   106.0
#
#                                             spoken_languages    status  \
# imdb_id
# tt0114709           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt0113497  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# tt0113228           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt0114885           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt0113041           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                      tagline  \
# imdb_id
# tt0114709                                                NaN
# tt0113497          Roll the dice and unleash the excitement!
# tt0113228  Still Yelling. Still Fighting. Still Ready for...
# tt0114885  Friends are the people who let you be yourself...
# tt0113041  Just When His World Is Back To Normal... He's ...
#
#                                  title  video vote_average vote_count
# imdb_id
# tt0114709                    Toy Story  False          7.7     5415.0
# tt0113497                      Jumanji  False          6.9     2413.0
# tt0113228             Grumpier Old Men  False          6.5       92.0
# tt0114885            Waiting to Exhale  False          6.1       34.0
# tt0113041  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 23 columns]

# %%
#Check Dataset Column Types
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45466 entries, tt0114709 to tt6980792
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   original_language      45455 non-null  object
#  7   original_title         45466 non-null  object
#  8   overview               44512 non-null  object
#  9   popularity             45461 non-null  object
#  10  poster_path            45080 non-null  object
#  11  production_companies   45463 non-null  object
#  12  production_countries   45463 non-null  object
#  13  release_date           45379 non-null  object
#  14  revenue                45460 non-null  float64
#  15  runtime                45203 non-null  float64
#  16  spoken_languages       45460 non-null  object
#  17  status                 45379 non-null  object
#  18  tagline                20412 non-null  object
#  19  title                  45460 non-null  object
#  20  video                  45460 non-null  object
#  21  vote_average           45460 non-null  float64
#  22  vote_count             45460 non-null  float64
# dtypes: float64(4), object(19)
# memory usage: 8.3+ MB

# %%
#Drop movies considered "Adult"
movies_df = movies_df.drop(movies_df[movies_df.adult == "True"].index)

# %%
#Drop movies that are not Released (Only Released movies would be considered for Oscars)
movies_df = movies_df.drop(movies_df[movies_df.status != "Released"].index)

# %%
#Drop columns not needed for Evaluation
movies_df= movies_df.drop(columns=["adult", "status", "homepage", "belongs_to_collection", "id","original_language", "overview", "poster_path", "spoken_languages", "tagline", "video"    ])
movies_df.head()
# Out:
#              budget                                             genres  \
# imdb_id
# tt0114709  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# tt0113497  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# tt0113228         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# tt0114885  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt0113041         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                         original_title popularity  \
# imdb_id
# tt0114709                    Toy Story  21.946943
# tt0113497                      Jumanji  17.015539
# tt0113228             Grumpier Old Men    11.7129
# tt0114885            Waiting to Exhale   3.859495
# tt0113041  Father of the Bride Part II   8.387519
#
#                                         production_companies  \
# imdb_id
# tt0114709     [{'name': 'Pixar Animation Studios', 'id': 3}]
# tt0113497  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# tt0113228  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# tt0114885  [{'name': 'Twentieth Century Fox Film Corporat...
# tt0113041  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                         production_countries release_date  \
# imdb_id
# tt0114709  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# tt0113497  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# tt0113228  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# tt0114885  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# tt0113041  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#                revenue  runtime                        title  vote_average  \
# imdb_id
# tt0114709  373554033.0     81.0                    Toy Story           7.7
# tt0113497  262797249.0    104.0                      Jumanji           6.9
# tt0113228          0.0    101.0             Grumpier Old Men           6.5
# tt0114885   81452156.0    127.0            Waiting to Exhale           6.1
# tt0113041   76578911.0    106.0  Father of the Bride Part II           5.7
#
#            vote_count
# imdb_id
# tt0114709      5415.0
# tt0113497      2413.0
# tt0113228        92.0
# tt0114885        34.0
# tt0113041       173.0

# %%
#Process Production Companies Column and set as first company in list
for index, row in movies_df.iterrows():    
    try:        
        companies = movies_df.loc[index, 'production_companies']        
        company = eval(companies)[0]['name']    
    except:        
        company = "Other"    
    movies_df.at[index, 'production'] = company

# %%
#Process Production Countries Column and set as first Country in list
for index, row in movies_df.iterrows():    
    try:        
        countries = movies_df.loc[index, 'production_countries']        
        country = eval(countries)[0]['name']    
    except:        
        country = "Other"    
    movies_df.at[index, 'country'] = country

# %%
#Process Genres Column and set as first genre in list
for index, row in movies_df.iterrows():    
    try:        
        genres = movies_df.loc[index, 'genres']        
        genre = eval(genres)[0]['name']    
    except:        
        genres = "Other"    
    movies_df.at[index, 'new_genre'] = genre

# %%
#Convert Release Date to contain just the year (Exact date is unnecessary)
movies_df['Release_year'] = movies_df['release_date'].str[:4]

# %%
#Check remaining columns
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44991 entries, tt0114709 to tt6980792
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                44991 non-null  object
#  1   genres                44991 non-null  object
#  2   original_title        44991 non-null  object
#  3   popularity            44991 non-null  object
#  4   production_companies  44991 non-null  object
#  5   production_countries  44991 non-null  object
#  6   release_date          44916 non-null  object
#  7   revenue               44991 non-null  float64
#  8   runtime               44742 non-null  float64
#  9   title                 44991 non-null  object
#  10  vote_average          44991 non-null  float64
#  11  vote_count            44991 non-null  float64
#  12  production            44991 non-null  object
#  13  country               44991 non-null  object
#  14  new_genre             44991 non-null  object
#  15  Release_year          44916 non-null  object
# dtypes: float64(4), object(12)
# memory usage: 7.1+ MB

# %%
#Verify Current Dataset
movies_df
# Out:
#              budget                                             genres  \
# imdb_id
# tt0114709  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# tt0113497  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# tt0113228         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# tt0114885  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt0113041         0                     [{'id': 35, 'name': 'Comedy'}]
# ...             ...                                                ...
# tt6209470         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# tt2028550         0                      [{'id': 18, 'name': 'Drama'}]
# tt0303758         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# tt0008536         0                                                 []
# tt6980792         0                                                 []
#
#                         original_title popularity  \
# imdb_id
# tt0114709                    Toy Story  21.946943
# tt0113497                      Jumanji  17.015539
# tt0113228             Grumpier Old Men    11.7129
# tt0114885            Waiting to Exhale   3.859495
# tt0113041  Father of the Bride Part II   8.387519
# ...                                ...        ...
# tt6209470                      رگ خواب   0.072051
# tt2028550          Siglo ng Pagluluwal   0.178241
# tt0303758                     Betrayal   0.903007
# tt0008536          Satana likuyushchiy   0.003503
# tt6980792                     Queerama   0.163015
#
#                                         production_companies  \
# imdb_id
# tt0114709     [{'name': 'Pixar Animation Studios', 'id': 3}]
# tt0113497  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# tt0113228  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# tt0114885  [{'name': 'Twentieth Century Fox Film Corporat...
# tt0113041  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                      ...
# tt6209470                                                 []
# tt2028550             [{'name': 'Sine Olivia', 'id': 19653}]
# tt0303758  [{'name': 'American World Pictures', 'id': 6165}]
# tt0008536               [{'name': 'Yermoliev', 'id': 88753}]
# tt6980792                                                 []
#
#                                         production_countries release_date  \
# imdb_id
# tt0114709  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# tt0113497  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# tt0113228  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# tt0114885  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# tt0113041  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                      ...          ...
# tt6209470             [{'iso_3166_1': 'IR', 'name': 'Iran'}]          NaN
# tt2028550      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# tt0303758  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# tt0008536           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# tt6980792   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#                revenue  runtime                        title  vote_average  \
# imdb_id
# tt0114709  373554033.0     81.0                    Toy Story           7.7
# tt0113497  262797249.0    104.0                      Jumanji           6.9
# tt0113228          0.0    101.0             Grumpier Old Men           6.5
# tt0114885   81452156.0    127.0            Waiting to Exhale           6.1
# tt0113041   76578911.0    106.0  Father of the Bride Part II           5.7
# ...                ...      ...                          ...           ...
# tt6209470          0.0     90.0                       Subdue           4.0
# tt2028550          0.0    360.0          Century of Birthing           9.0
# tt0303758          0.0     90.0                     Betrayal           3.8
# tt0008536          0.0     87.0             Satan Triumphant           0.0
# tt6980792          0.0     75.0                     Queerama           0.0
#
#            vote_count                              production  \
# imdb_id
# tt0114709      5415.0                 Pixar Animation Studios
# tt0113497      2413.0                        TriStar Pictures
# tt0113228        92.0                            Warner Bros.
# tt0114885        34.0  Twentieth Century Fox Film Corporation
# tt0113041       173.0                   Sandollar Productions
# ...               ...                                     ...
# tt6209470         1.0                                   Other
# tt2028550         3.0                             Sine Olivia
# tt0303758         6.0                 American World Pictures
# tt0008536         0.0                               Yermoliev
# tt6980792         0.0                                   Other
#
#                             country  new_genre Release_year
# imdb_id
# tt0114709  United States of America  Animation         1995
# tt0113497  United States of America  Adventure         1995
# tt0113228  United States of America    Romance         1995
# tt0114885  United States of America     Comedy         1995
# tt0113041  United States of America     Comedy         1995
# ...                             ...        ...          ...
# tt6209470                      Iran      Drama          NaN
# tt2028550               Philippines      Drama         2011
# tt0303758  United States of America     Action         2003
# tt0008536                    Russia     Action         1917
# tt6980792            United Kingdom     Action         2017
#
# [44991 rows x 16 columns]

# %%
#Drop processed columns, keeping only clean dataset
movies_df= movies_df.drop(columns=["genres", "production_companies", "production_countries", "release_date"])
movies_df.head()
# Out:
#              budget               original_title popularity      revenue  \
# imdb_id
# tt0114709  30000000                    Toy Story  21.946943  373554033.0
# tt0113497  65000000                      Jumanji  17.015539  262797249.0
# tt0113228         0             Grumpier Old Men    11.7129          0.0
# tt0114885  16000000            Waiting to Exhale   3.859495   81452156.0
# tt0113041         0  Father of the Bride Part II   8.387519   76578911.0
#
#            runtime                        title  vote_average  vote_count  \
# imdb_id
# tt0114709     81.0                    Toy Story           7.7      5415.0
# tt0113497    104.0                      Jumanji           6.9      2413.0
# tt0113228    101.0             Grumpier Old Men           6.5        92.0
# tt0114885    127.0            Waiting to Exhale           6.1        34.0
# tt0113041    106.0  Father of the Bride Part II           5.7       173.0
#
#                                        production                   country  \
# imdb_id
# tt0114709                 Pixar Animation Studios  United States of America
# tt0113497                        TriStar Pictures  United States of America
# tt0113228                            Warner Bros.  United States of America
# tt0114885  Twentieth Century Fox Film Corporation  United States of America
# tt0113041                   Sandollar Productions  United States of America
#
#            new_genre Release_year
# imdb_id
# tt0114709  Animation         1995
# tt0113497  Adventure         1995
# tt0113228    Romance         1995
# tt0114885     Comedy         1995
# tt0113041     Comedy         1995

# %%
#Set index to IMDB ID
#movies_df.set_index("imdb_id")

# %%
#Convert Budget and Popularty colums from Object to Numbers
movies_df['budget']=movies_df.budget.astype('int64')
movies_df['popularity']=movies_df.budget.astype('float64')

# %%
#Drop any rows containing blank data
movies_df = movies_df.dropna(axis = 0,how= 'any')

# %%
#Check final dataset numbers
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44678 entries, tt0114709 to tt6980792
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   budget          44678 non-null  int64
#  1   original_title  44678 non-null  object
#  2   popularity      44678 non-null  float64
#  3   revenue         44678 non-null  float64
#  4   runtime         44678 non-null  float64
#  5   title           44678 non-null  object
#  6   vote_average    44678 non-null  float64
#  7   vote_count      44678 non-null  float64
#  8   production      44678 non-null  object
#  9   country         44678 non-null  object
#  10  new_genre       44678 non-null  object
#  11  Release_year    44678 non-null  object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 4.4+ MB

# %%
#Export dataset to CSV
movies_df.to_csv(write_file)
